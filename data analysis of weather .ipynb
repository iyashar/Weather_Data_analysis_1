# %% [markdown]
# # Data analysis of weather

# %% [markdown]
# ## The weather dataset

# %% [markdown]
# The data is available in CSV file . I am going to analyze it using pandas DataFrame and using Lux to toggle between data and virtualization

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"1. Weather Data.csv")

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Date/Time']=data['Date/Time'].astype('datetime64').replace('True')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %% [markdown]
# ### Exploring data

# %%
data.head()    # first five rows
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.tail()   #last five rows
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 8779               30            9.7     100.13    Snow
# 8780               24            9.7     100.03    Snow
# 8781               28            4.8      99.95    Snow
# 8782               28            9.7      99.91    Snow
# 8783               30           11.3      99.89    Snow

# %% [markdown]
# #### Checking rows and columns of dataframe

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# #### Name of columns

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# #### checking data types of columns

# %% [markdown]
# #### checking unique values present in weather column

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# #### checking how many unique value are present in weather columns

# %%
data['Weather'].nunique()
# Out:
# 50

# %% [markdown]
# so,50 uniques value are present from around 8k rows

# %% [markdown]
# #### lets check it in whole dataFrame

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# #### checking non null values from dataFrame using count() methods

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# Woah,There are no null values its good news for us

# %% [markdown]
# #### Lets see unique values count from a column

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# #### Wow,Out of 8784 times weather is mainly clear 2106 times

# %% [markdown]
# #### Let see basic information on data frame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %% [markdown]
# ## Adding some Visuals for better understanding data

# %%
import seaborn as sns

# %%
g = sns.PairGrid(data)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
g = sns.JointGrid(data=data, x="Temp_C", y="Dew Point Temp_C")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)

# %% [markdown]
# ## Now,time for solving some questions

# %% [markdown]
# #### 1. Find all the unique 'Wind Speed' values in the data.

# %%
df = data['Wind Speed_km/h'].unique()
df
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
sns.histplot(df)
# Out:
# <AxesSubplot: ylabel='Count'>

# %% [markdown]
# #### 2.Find the number of times when the weather is exactly clear

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# Weather is clear 1326 times

# %% [markdown]
# #### Getting data frame when weather is clear

# %%
data[data.Weather == 'Clear']
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 114  2012-01-05 18:00:00    -7.1             -14.4         56
# 115  2012-01-05 19:00:00    -9.2             -15.4         61
# 116  2012-01-05 20:00:00    -9.8             -15.7         62
# 117  2012-01-05 21:00:00    -9.0             -14.8         63
# ...                  ...     ...               ...        ...
# 8646 2012-12-26 06:00:00   -13.4             -14.8         89
# 8698 2012-12-28 10:00:00    -6.1              -8.6         82
# 8713 2012-12-29 01:00:00   -11.9             -13.6         87
# 8714 2012-12-29 02:00:00   -11.8             -13.1         90
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %%
df = data[data.Weather == 'Clear']
df
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 114  2012-01-05 18:00:00    -7.1             -14.4         56
# 115  2012-01-05 19:00:00    -9.2             -15.4         61
# 116  2012-01-05 20:00:00    -9.8             -15.7         62
# 117  2012-01-05 21:00:00    -9.0             -14.8         63
# ...                  ...     ...               ...        ...
# 8646 2012-12-26 06:00:00   -13.4             -14.8         89
# 8698 2012-12-28 10:00:00    -6.1              -8.6         82
# 8713 2012-12-29 01:00:00   -11.9             -13.6         87
# 8714 2012-12-29 02:00:00   -11.8             -13.1         90
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %%
sns.histplot(df['Temp_C'])
# Out:
# <AxesSubplot: xlabel='Temp_C', ylabel='Count'>

# %% [markdown]
# Usually Temprature was over 0 when the weather was clear

# %% [markdown]
# #### 3.Finding out number of times when the wind speed was exactly 4 km/h.

# %%
data.groupby('Wind Speed_km/h').get_group(4)
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 96   2012-01-05 00:00:00    -8.8             -11.7         79
# 101  2012-01-05 05:00:00    -7.0              -9.5         82
# 146  2012-01-07 02:00:00    -8.1             -11.1         79
# ...                  ...     ...               ...        ...
# 8768 2012-12-31 08:00:00    -8.6             -10.3         87
# 8769 2012-12-31 09:00:00    -8.1              -9.6         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
# 8772 2012-12-31 12:00:00    -5.8              -7.5         88
# 8773 2012-12-31 13:00:00    -4.6              -6.6         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 0                   4            8.0     101.24           Fog
# 1                   4            8.0     101.24           Fog
# ...

# %%
data[data['Wind Speed_km/h'] == 4]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 96   2012-01-05 00:00:00    -8.8             -11.7         79
# 101  2012-01-05 05:00:00    -7.0              -9.5         82
# 146  2012-01-07 02:00:00    -8.1             -11.1         79
# ...                  ...     ...               ...        ...
# 8768 2012-12-31 08:00:00    -8.6             -10.3         87
# 8769 2012-12-31 09:00:00    -8.1              -9.6         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
# 8772 2012-12-31 12:00:00    -5.8              -7.5         88
# 8773 2012-12-31 13:00:00    -4.6              -6.6         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 0                   4            8.0     101.24           Fog
# 1                   4            8.0     101.24           Fog
# ...

# %% [markdown]
# Hence,Wind speed is 4km/h 474 times.

# %% [markdown]
# #### 4.Find out the null values in the data

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# Hence, There are no null values

# %% [markdown]
# #### 5.Rename the column name 'Weather' of the dataframe to 'Weather Condition'

# %%
data.rename(columns = {'Weather' : 'Weather Condition'},inplace = True)

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# #### 6. Find the mean of Visibility_km.

# %%
data['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %%
sns.displot(data, x="Visibility_km", kind="kde")

# %% [markdown]
# Hence, The average visiblity is 27.66444672131151

# %% [markdown]
# #### 7. What is the standard deviation of pressure in the data

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %%
import matplotlib.pyplot as plt
def plot_errorbars(arg, **kws):
    np.random.seed(sum(map(ord, "error_bars")))
    x = data['Press_kPa']
    f, axs = plt.subplots(2, figsize=(7, 2), sharex=True, layout="tight")
    sns.pointplot(x=x, errorbar=arg, **kws, capsize=.3, ax=axs[0])
    sns.stripplot(x=x, jitter=.3, ax=axs[1])

# %%
plot_errorbars("sd")

# %% [markdown]
# The deviation between  pressure is 0.8440047459486474

# %% [markdown]
# #### 8.What is the variance of "Relative Humidity" in data ?

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# There is high fluctuation in humidity and its variance is 286.2485501984998

# %% [markdown]
# #### 9. Find all the instances when snow was recorded

# %%
data['Weather Condition'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# Snow was recorded 390 times

# %% [markdown]
# #### 10. Find all the instances when 'Wind Speed is above 24 'and 'visiblity is 25'.

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 23   2012-01-01 23:00:00     5.3               2.0         79
# 24   2012-01-02 00:00:00     5.2               1.5         77
# 25   2012-01-02 01:00:00     4.6               0.0         72
# 26   2012-01-02 02:00:00     3.9              -0.9         71
# 27   2012-01-02 03:00:00     3.7              -1.5         69
# ...                  ...     ...               ...        ...
# 8705 2012-12-28 17:00:00    -8.6             -12.0         76
# 8753 2012-12-30 17:00:00   -12.1             -15.8         74
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8759 2012-12-30 23:00:00   -12.1             -15.1         78
# 8760 2012-12-31 00:00:00   -11.1             -14.4         77
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 23                 30           25.0      99.31            Cloudy
# 24                 35           25.0      99.26      Rain Showers
# ...

# %% [markdown]
# hence, 308 times 'Wind Speed is above 24 'and 'visiblity is 25'.¶

# %% [markdown]
# #### 11.What is the Mean value of each column against each 'Weather Condition'.

# %%
data.groupby('Weather Condition').mean()
# Out:
# C:\Users\Yasha\AppData\Local\Temp\ipykernel_19816\17017135.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Weather Condition').mean()
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# ...

# %%
data.groupby('Weather Condition').min()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather Condition
# Clear                                   2012-01-03 19:00:00   -23.3
# Cloudy                                  2012-01-01 17:00:00   -21.4
# Drizzle                                 2012-01-23 21:00:00     1.1
# Drizzle,Fog                             2012-01-23 20:00:00     0.0
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-17 15:00:00     0.9
# Drizzle,Snow,Fog                        2012-12-18 21:00:00     0.3
# Fog                                     2012-01-01 00:00:00   -16.0
# Freezing Drizzle                        2012-01-07 11:00:00    -9.0
# Freezing Drizzle,Fog                    2012-01-01 02:00:00    -6.4
# Freezing Drizzle,Haze                   2012-02-01 11:00:00    -5.8
# Freezing Drizzle,Snow                   2012-01-13 03:00:00    -8.3
# ...

# %% [markdown]
# #### 12. What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
data.groupby('Weather Condition').max()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather Condition
# Clear                                   2012-12-30 20:00:00    32.8
# Cloudy                                  2012-12-31 06:00:00    30.5
# Drizzle                                 2012-12-22 01:00:00    18.8
# Drizzle,Fog                             2012-12-19 10:00:00    19.9
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-19 18:00:00     1.2
# Drizzle,Snow,Fog                        2012-12-22 03:00:00     1.1
# Fog                                     2012-12-29 10:00:00    20.8
# Freezing Drizzle                        2012-12-17 00:00:00    -2.3
# Freezing Drizzle,Fog                    2012-12-10 05:00:00    -0.3
# Freezing Drizzle,Haze                   2012-02-01 13:00:00    -5.0
# Freezing Drizzle,Snow                   2012-12-28 02:00:00    -3.3
# ...

# %% [markdown]
# #### 13.Show all the Records where Weather Condition is Fog.

# %% [markdown]
# ##### where the weather was exactly just Fog!

# %%
data[data['Weather Condition'] == 'Fog']
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# 5    2012-01-01 05:00:00    -1.4              -3.3         87
# 6    2012-01-01 06:00:00    -1.5              -3.1         89
# ...                  ...     ...               ...        ...
# 8716 2012-12-29 04:00:00   -16.0             -17.2         90
# 8717 2012-12-29 05:00:00   -14.8             -15.9         91
# 8718 2012-12-29 06:00:00   -13.8             -15.3         88
# 8719 2012-12-29 07:00:00   -14.8             -16.4         88
# 8722 2012-12-29 10:00:00   -12.0             -13.3         90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 0                   4            8.0     101.24               Fog
# 1                   4            8.0     101.24               Fog
# ...

# %% [markdown]
# ##### where the weather was Fog too!

# %%
data[data['Weather Condition'].str.contains('Fog', na=False)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8739 2012-12-30 03:00:00    -9.1             -10.4         90
# 8740 2012-12-30 04:00:00    -9.3             -10.6         90
# 8741 2012-12-30 05:00:00    -9.1             -10.4         90
# 8742 2012-12-30 06:00:00    -9.3             -10.8         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     Weather Condition
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# #### 14. Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# ...                  ...     ...               ...        ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 67                 24           25.0     101.74             Clear
# 106                17           48.3     100.45      Mainly Clear
# ...

# %% [markdown]
# #### 15.  Find all instances when :
# #### A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# #### or
# #### B. 'Visibility is above 40'

# %%
data[((data['Weather Condition'] == 'clear') & (data['Rel Hum_%'] > 50 )) | (data['Visibility_km'] > 40)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# 110  2012-01-05 14:00:00    -5.1             -10.7         65
# ...                  ...     ...               ...        ...
# 8748 2012-12-30 12:00:00   -12.2             -15.7         75
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 106                17           48.3     100.45      Mainly Clear
# 107                22           48.3     100.41      Mainly Clear
# ...
